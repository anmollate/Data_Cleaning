# %%
#importing pandas
import pandas as pd

# %%
df=pd.read_csv('dirty_cafe_sales.csv')

# %% [markdown]
# #Getting The Data

# %%
df.head(10)
# Out:
#   Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0    TXN_1961373    Coffee        2            2.0         4.0
# 1    TXN_4977031      Cake        4            3.0        12.0
# 2    TXN_4271903    Cookie        4            1.0       ERROR
# 3    TXN_7034554     Salad        2            5.0        10.0
# 4    TXN_3160411    Coffee        2            2.0         4.0
# 5    TXN_2602893  Smoothie        5            4.0        20.0
# 6    TXN_4433211   UNKNOWN        3            3.0         9.0
# 7    TXN_6699534  Sandwich        4            4.0        16.0
# 8    TXN_4717867       NaN        5            3.0        15.0
# 9    TXN_2064365  Sandwich        5            4.0        20.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11
# 5     Credit Card       NaN       2023-03-31
# 6           ERROR  Takeaway       2023-10-06
# 7            Cash   UNKNOWN       2023-10-28
# 8             NaN  Takeaway       2023-07-28
# 9             NaN  In-store       2023-12-31

# %% [markdown]
# Getting The Count Of Missing Values In The Item Column

# %%
(df['Item']=='UNKNOWN').sum()
# Out:
# np.int64(344)

# %%
#Getting The Total Number Of Columns
print(df['Transaction ID'].value_counts())
# Out:
# Transaction ID
# TXN_6170729    1
# TXN_1961373    1
# TXN_4977031    1
# TXN_4271903    1
# TXN_7034554    1
#               ..
# TXN_3709394    1
# TXN_3522028    1
# TXN_3567645    1
# TXN_5132361    1
# TXN_2616390    1
# Name: count, Length: 10000, dtype: int64

# %%
df.head(20)
# Out:
#    Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0     TXN_1961373    Coffee        2            2.0         4.0
# 1     TXN_4977031      Cake        4            3.0        12.0
# 2     TXN_4271903    Cookie        4            1.0       ERROR
# 3     TXN_7034554     Salad        2            5.0        10.0
# 4     TXN_3160411    Coffee        2            2.0         4.0
# 5     TXN_2602893  Smoothie        5            4.0        20.0
# 6     TXN_4433211   UNKNOWN        3            3.0         9.0
# 7     TXN_6699534  Sandwich        4            4.0        16.0
# 8     TXN_4717867       NaN        5            3.0        15.0
# 9     TXN_2064365  Sandwich        5            4.0        20.0
# 10    TXN_2548360     Salad        5            5.0        25.0
# 11    TXN_3051279  Sandwich        2            4.0         8.0
# 12    TXN_7619095  Sandwich        2            4.0         8.0
# 13    TXN_9437049    Cookie        5            1.0         5.0
# 14    TXN_8915701     ERROR        2            1.5         3.0
# 15    TXN_2847255     Salad        3            5.0        15.0
# 16    TXN_3765707  Sandwich        1            4.0         4.0
# 17    TXN_6769710     Juice        2            3.0         6.0
# 18    TXN_8876618      Cake        5            3.0        15.0
# 19    TXN_3709394     Juice        4            3.0        12.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3          UNKNOWN   UNKNOWN       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card       NaN       2023-03-31
# 6            ERROR  Takeaway       2023-10-06
# 7             Cash   UNKNOWN       2023-10-28
# 8              NaN  Takeaway       2023-07-28
# 9              NaN  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway            ERROR
# 12            Cash  In-store       2023-05-03
# 13             NaN  Takeaway       2023-06-01
# 14             NaN  In-store       2023-03-21
# 15     Credit Card  In-store       2023-11-15
# 16             NaN       NaN       2023-06-10
# 17            Cash  In-store       2023-02-24
# 18            Cash     ERROR       2023-03-25
# 19            Cash  Takeaway       2023-01-15

# %%
(df['Item']=='ERROR').sum()
# Out:
# np.int64(292)

# %%
df['Item'].unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', 'UNKNOWN',
#        'Sandwich', nan, 'ERROR', 'Juice', 'Tea'], dtype=object)

# %%
df=df.dropna(subset=['Item'])

# %%
df['Item'].unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', 'UNKNOWN',
#        'Sandwich', 'ERROR', 'Juice', 'Tea'], dtype=object)

# %%
df=df[df['Item']!='ERROR']

# %%
df['Item'].unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', 'UNKNOWN',
#        'Sandwich', 'Juice', 'Tea'], dtype=object)

# %%
df=df[df['Item']!='UNKNOWN']

# %%
df["Transaction ID"].value_counts()
# Out:
# Transaction ID
# TXN_6170729    1
# TXN_1961373    1
# TXN_4977031    1
# TXN_4271903    1
# TXN_7034554    1
#               ..
# TXN_7619095    1
# TXN_9437049    1
# TXN_2847255    1
# TXN_3765707    1
# TXN_6769710    1
# Name: count, Length: 9031, dtype: int64

# %%
df['Item'].unique()
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', 'Sandwich',
#        'Juice', 'Tea'], dtype=object)

# %%
df['Quantity'].unique()
# Out:
# array(['2', '4', '5', '3', '1', 'ERROR', 'UNKNOWN', nan], dtype=object)

# %%
df=df.dropna(subset=['Quantity'])

# %%
df['Quantity'].unique()
# Out:
# array(['2', '4', '5', '3', '1', 'ERROR', 'UNKNOWN'], dtype=object)

# %%
df=df[df['Quantity']!='ERROR']
df=df[df['Quantity']!='UNKNOWN']

# %%
df['Quantity'].unique()
# Out:
# array(['2', '4', '5', '3', '1'], dtype=object)

# %%
df['Price Per Unit'].unique()
# Out:
# array(['2.0', '3.0', '1.0', '5.0', '4.0', '1.5', nan, 'ERROR', 'UNKNOWN'],
#       dtype=object)

# %%
df=df.dropna(subset=['Price Per Unit'])

# %%
df['Price Per Unit'].unique()
# Out:
# array(['2.0', '3.0', '1.0', '5.0', '4.0', '1.5', 'ERROR', 'UNKNOWN'],
#       dtype=object)

# %%
df=df[df['Price Per Unit']!='UNKNOWN']

# %%
df['Price Per Unit'].unique()
# Out:
# array(['2.0', '3.0', '1.0', '5.0', '4.0', '1.5', 'ERROR'], dtype=object)

# %%
df=df[df['Price Per Unit']!='ERROR']

# %%
df['Price Per Unit'].unique()
# Out:
# array(['2.0', '3.0', '1.0', '5.0', '4.0', '1.5'], dtype=object)

# %%
df['Total Spent'].unique()
# Out:
# array(['4.0', '12.0', 'ERROR', '10.0', '20.0', '16.0', '25.0', '8.0',
#        '5.0', '15.0', '6.0', nan, 'UNKNOWN', '2.0', '9.0', '1.0', '3.0',
#        '7.5', '1.5', '4.5'], dtype=object)

# %%
df=df.dropna(subset=['Total Spent'])
df=df[df['Total Spent']!='ERROR']
df=df[df['Total Spent']!='UNKNOWN']

# %%
df['Total Spent'].unique()
# Out:
# array(['4.0', '12.0', '10.0', '20.0', '16.0', '25.0', '8.0', '5.0',
#        '15.0', '6.0', '2.0', '9.0', '1.0', '3.0', '7.5', '1.5', '4.5'],
#       dtype=object)

# %%
df['Transaction ID'].value_counts()
# Out:
# Transaction ID
# TXN_6170729    1
# TXN_1961373    1
# TXN_4977031    1
# TXN_7034554    1
# TXN_3160411    1
#               ..
# TXN_7640952    1
# TXN_9677376    1
# TXN_8853997    1
# TXN_9130559    1
# TXN_1080432    1
# Name: count, Length: 7732, dtype: int64

# %%
df['Payment Method'].unique()
# Out:
# array(['Credit Card', 'Cash', 'UNKNOWN', 'Digital Wallet', nan, 'ERROR'],
#       dtype=object)

# %%
df['Payment Method']=df['Payment Method'].fillna('UNKNOWN')

# %%
df['Payment Method'].unique()
# Out:
# array(['Credit Card', 'Cash', 'UNKNOWN', 'Digital Wallet', 'ERROR'],
#       dtype=object)

# %%
df['Payment Method']=df['Payment Method'].replace('ERROR','UNKNOWN')

# %%
df['Payment Method'].unique()
# Out:
# array(['Credit Card', 'Cash', 'UNKNOWN', 'Digital Wallet'], dtype=object)

# %%
df.head(20)
# Out:
#    Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0     TXN_1961373    Coffee        2            2.0         4.0
# 1     TXN_4977031      Cake        4            3.0        12.0
# 3     TXN_7034554     Salad        2            5.0        10.0
# 4     TXN_3160411    Coffee        2            2.0         4.0
# 5     TXN_2602893  Smoothie        5            4.0        20.0
# 7     TXN_6699534  Sandwich        4            4.0        16.0
# 9     TXN_2064365  Sandwich        5            4.0        20.0
# 10    TXN_2548360     Salad        5            5.0        25.0
# 11    TXN_3051279  Sandwich        2            4.0         8.0
# 12    TXN_7619095  Sandwich        2            4.0         8.0
# 13    TXN_9437049    Cookie        5            1.0         5.0
# 15    TXN_2847255     Salad        3            5.0        15.0
# 16    TXN_3765707  Sandwich        1            4.0         4.0
# 17    TXN_6769710     Juice        2            3.0         6.0
# 18    TXN_8876618      Cake        5            3.0        15.0
# 19    TXN_3709394     Juice        4            3.0        12.0
# 21    TXN_3567645  Smoothie        4            4.0        16.0
# 22    TXN_5132361  Sandwich        3            4.0        12.0
# 23    TXN_2616390  Sandwich        2            4.0         8.0
# 24    TXN_9400181  Sandwich        5            4.0        20.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 3          UNKNOWN   UNKNOWN       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card       NaN       2023-03-31
# 7             Cash   UNKNOWN       2023-10-28
# 9          UNKNOWN  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway            ERROR
# 12            Cash  In-store       2023-05-03
# 13         UNKNOWN  Takeaway       2023-06-01
# 15     Credit Card  In-store       2023-11-15
# 16         UNKNOWN       NaN       2023-06-10
# 17            Cash  In-store       2023-02-24
# 18            Cash     ERROR       2023-03-25
# 19            Cash  Takeaway       2023-01-15
# 21     Credit Card  Takeaway       2023-03-30
# 22  Digital Wallet  Takeaway       2023-12-01
# 23         UNKNOWN       NaN       2023-09-18
# 24            Cash  In-store       2023-06-03

# %%
df['Location'].unique()
# Out:
# array(['Takeaway', 'In-store', 'UNKNOWN', nan, 'ERROR'], dtype=object)

# %%
df['Location']=df['Location'].fillna('UNKNOWN')

# %%
df['Location']=df['Location'].replace('ERROR','UNKNOWN')

# %%
df['Location'].unique()
# Out:
# array(['Takeaway', 'In-store', 'UNKNOWN'], dtype=object)

# %%
df['Transaction Date'].isna().sum()
# Out:
# np.int64(116)

# %%
df['Transaction Date'].notnull().sum()
# Out:
# np.int64(7616)

# %%
df['Transaction Date']=df['Transaction Date'].fillna("UNKNOWN")
df['Transaction Date']=df['Transaction Date'].replace('ERROR','UNKNOWN')

# %%
df['Transaction Date'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Transaction Date'].nunique()
# Out:
# 366

# %%
df.head(20)
# Out:
#    Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0     TXN_1961373    Coffee        2            2.0         4.0
# 1     TXN_4977031      Cake        4            3.0        12.0
# 3     TXN_7034554     Salad        2            5.0        10.0
# 4     TXN_3160411    Coffee        2            2.0         4.0
# 5     TXN_2602893  Smoothie        5            4.0        20.0
# 7     TXN_6699534  Sandwich        4            4.0        16.0
# 9     TXN_2064365  Sandwich        5            4.0        20.0
# 10    TXN_2548360     Salad        5            5.0        25.0
# 11    TXN_3051279  Sandwich        2            4.0         8.0
# 12    TXN_7619095  Sandwich        2            4.0         8.0
# 13    TXN_9437049    Cookie        5            1.0         5.0
# 15    TXN_2847255     Salad        3            5.0        15.0
# 16    TXN_3765707  Sandwich        1            4.0         4.0
# 17    TXN_6769710     Juice        2            3.0         6.0
# 18    TXN_8876618      Cake        5            3.0        15.0
# 19    TXN_3709394     Juice        4            3.0        12.0
# 21    TXN_3567645  Smoothie        4            4.0        16.0
# 22    TXN_5132361  Sandwich        3            4.0        12.0
# 23    TXN_2616390  Sandwich        2            4.0         8.0
# 24    TXN_9400181  Sandwich        5            4.0        20.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 3          UNKNOWN   UNKNOWN       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card   UNKNOWN       2023-03-31
# 7             Cash   UNKNOWN       2023-10-28
# 9          UNKNOWN  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway          UNKNOWN
# 12            Cash  In-store       2023-05-03
# 13         UNKNOWN  Takeaway       2023-06-01
# 15     Credit Card  In-store       2023-11-15
# 16         UNKNOWN   UNKNOWN       2023-06-10
# 17            Cash  In-store       2023-02-24
# 18            Cash   UNKNOWN       2023-03-25
# 19            Cash  Takeaway       2023-01-15
# 21     Credit Card  Takeaway       2023-03-30
# 22  Digital Wallet  Takeaway       2023-12-01
# 23         UNKNOWN   UNKNOWN       2023-09-18
# 24            Cash  In-store       2023-06-03
